# %%
import pandas as pd

# %% [markdown]
# #### Import the libraries pandas,matplot.pyplot an seaborn from python,in ordr tp perform coulmn operations on dataset

# %%
sample=pd.read_csv("D:/flipkart_smartphones.csv")

# %%
sample
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %%
sample.columns
# Out:
# Index(['brand', 'model', 'colour', 'original_price', 'discounted_price',
#        'ratings', 'rating_count', 'reviews', 'memory', 'storage', 'processor',
#        'rear_camera', 'front_camera', 'display_size', 'battery_capacity',
#        'battery_type'],
#       dtype='object')

# %% [markdown]
# #### Displaying the variables names in the data set

# %%
sample['total']=sample['original_price']+sample['discounted_price']

# %%
sample
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %% [markdown]
# #### Added a new variables in the dataset bycombining the variables

# %%
sample['low']=sample['rating_count']/sample['reviews']

# %%
sample
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %%
sample.rename(columns={'reviews':'review'})
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  review  memory  storage  \
# 0               14499      4.5         87331    6044     4.0    128.0
# ...

# %% [markdown]
# #### Renamed a reviews variables as review

# %%
sample.rename(columns={'brand':'brands','model':'models'})
# Out:
#      brands            models               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %% [markdown]
# #### Renamed Two variables brand as brands and model as models

# %%
sample.drop(['rear_camera','front_camera'],axis=1)
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %% [markdown]
# #### We have droped the two variables rear_camera and front_camera from the dataset

# %%
sample.columns=[col.upper()for col in sample.columns]

# %%
sample
# Out:
#       BRAND             MODEL               COLOUR  ORIGINAL_PRICE  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      DISCOUNTED_PRICE  RATINGS  RATING_COUNT  REVIEWS  MEMORY  STORAGE  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %% [markdown]
# #### Displayed the variables name of the dataset in the uppercase

# %%
sample.columns=[col.lower()for col in sample.columns]

# %%
sample
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %% [markdown]
# #### Displayed the variables name of the dataset in the Lowercase

# %%
sample.sort_values(by=['total','low'],ascending=[True,False])
# Out:
#        brand                         model          colour  original_price  \
# 446     ITEL                    ITEL A23S       Ocean Blue            4899
# 488     ITEL                    ITEL A23S         Sky Cyan            4899
# 505     ITEL                     ITEL A49   Crystal Purple            5799
# 745     ITEL                     ITEL A27        Deep Grey            6999
# 744     ITEL                     ITEL A27     Crystal Blue            6999
# ..       ...                           ...             ...             ...
# 764    APPLE          APPLE IPHONE 14 PRO      Space Black          139900
# 789    APPLE          APPLE IPHONE 14 PRO      Deep Purple          139900
# 665    APPLE          APPLE IPHONE 13 PRO           Silver          149900
# 771  SAMSUNG  SAMSUNG GALAXY S23 ULTRA 5G    Phantom Black          149999
# 520    APPLE          APPLE IPHONE 14 PRO      Space Black          159900
#
# ...

# %% [markdown]
# #### In this we have sorted two variables 'Total' and 'Low' and then we have arranged the variables Total in the ascending order

# %%
sample.sort_values(by='total', ascending=True)
# Out:
#        brand                         model          colour  original_price  \
# 488     ITEL                    ITEL A23S         Sky Cyan            4899
# 446     ITEL                    ITEL A23S       Ocean Blue            4899
# 505     ITEL                     ITEL A49   Crystal Purple            5799
# 745     ITEL                     ITEL A27        Deep Grey            6999
# 744     ITEL                     ITEL A27     Crystal Blue            6999
# ..       ...                           ...             ...             ...
# 764    APPLE          APPLE IPHONE 14 PRO      Space Black          139900
# 665    APPLE          APPLE IPHONE 13 PRO           Silver          149900
# 789    APPLE          APPLE IPHONE 14 PRO      Deep Purple          139900
# 771  SAMSUNG  SAMSUNG GALAXY S23 ULTRA 5G    Phantom Black          149999
# 520    APPLE          APPLE IPHONE 14 PRO      Space Black          159900
#
# ...

# %% [markdown]
# #### Sorted the variables named 'Total' and arranged its values in ascending order

# %%
sample.sort_values(by='total')
# Out:
#        brand                         model          colour  original_price  \
# 488     ITEL                    ITEL A23S         Sky Cyan            4899
# 446     ITEL                    ITEL A23S       Ocean Blue            4899
# 505     ITEL                     ITEL A49   Crystal Purple            5799
# 745     ITEL                     ITEL A27        Deep Grey            6999
# 744     ITEL                     ITEL A27     Crystal Blue            6999
# ..       ...                           ...             ...             ...
# 764    APPLE          APPLE IPHONE 14 PRO      Space Black          139900
# 665    APPLE          APPLE IPHONE 13 PRO           Silver          149900
# 789    APPLE          APPLE IPHONE 14 PRO      Deep Purple          139900
# 771  SAMSUNG  SAMSUNG GALAXY S23 ULTRA 5G    Phantom Black          149999
# 520    APPLE          APPLE IPHONE 14 PRO      Space Black          159900
#
# ...

# %% [markdown]
# #### We have sorted the variable named 'Total'

# %%
sample.drop(['low'],axis=1,inplace=True)

# %%
sample
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %% [markdown]
# #### We have dropped the variables named 'low' and inplace function

# %%
sample.groupby('brand').count()
# Out:
#           model  colour  original_price  discounted_price  ratings  \
# brand
# APPLE        58      53              58                58       58
# GOOGLE        4       4               4                 4        4
# I KALL        4       4               4                 4        4
# INFINIX      71      71              71                71       71
# IQOO         18      18              18                18       18
# ITEL         18      18              18                18       18
# LAVA          6       6               6                 6        6
# MARQ          1       1               1                 1        1
# MICROMAX      3       3               3                 3        3
# MOTOROLA     53      53              53                53       53
# NOKIA         5       5               5                 5        5
# NOTHING       5       5               5                 5        5
# ONEPLUS       9       9               9                 9        9
# ...

# %% [markdown]
# #### By performing groupby function on post variable and used count function it is displays us this variable takes place in 835 observations

# %%
sample=pd.read_csv("D:/flipkart_smartphones.csv")

# %%
sample
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %%
print(sample['ratings'].isnull().sum())
# Out:
# 1

# %% [markdown]
# #### We have found out that there are one null values presesnt in the 'Ratings' variable.

# %%
print(sample.columns.values)
# Out:
# ['brand' 'model' 'colour' 'original_price' 'discounted_price' 'ratings'
#  'rating_count' 'reviews' 'memory' 'storage' 'processor' 'rear_camera'
#  'front_camera' 'display_size' 'battery_capacity' 'battery_type']

# %% [markdown]
# #### Displayed the variables but by using print function
